# %%
import pandas as pd

#taking csv file
fifa_data=pd.read_csv('E:\DBMI\Mini Project\FIFA18CompletePlayerDataset.csv', index_col=0)
fifa_data.describe()
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (23,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                 Age       Overall     Potential       Special           CAM  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  15952.000000
# mean      25.144541     66.247984     71.190813   1594.095100     59.251755
# std        4.614272      6.987965      6.102199    272.151435      9.880164
# min       16.000000     46.000000     46.000000    728.000000     27.000000
# 25%       21.000000     62.000000     67.000000   1449.000000     53.000000
# 50%       25.000000     66.000000     71.000000   1633.000000     60.000000
# 75%       28.000000     71.000000     75.000000   1786.000000     66.000000
# max       47.000000     94.000000     94.000000   2291.000000     92.000000
#
# ...

# %%
#finding size of dataset
fifa_data.shape
# Out:
# (17981, 74)

# %%
#columns present in our dataset
fifa_data.columns
# Out:
# Index(['Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential',
#        'Club', 'Club Logo', 'Value', 'Wage', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
#finding if any value is missing
fifa_data.isna().values.any()
# Out:
# True

# %%
#answer came as True, count of missing values
fifa_data.isna().sum().sum()
# Out:
# 53002

# %%
#copying actual file in new file
data=fifa_data.copy()
data.head(10)
# Out:
#                 Name  Age                                            Photo  \
# 0  Cristiano Ronaldo   32   https://cdn.sofifa.org/48/18/players/20801.png
# 1           L. Messi   30  https://cdn.sofifa.org/48/18/players/158023.png
# 2             Neymar   25  https://cdn.sofifa.org/48/18/players/190871.png
# 3          L. Suárez   30  https://cdn.sofifa.org/48/18/players/176580.png
# 4           M. Neuer   31  https://cdn.sofifa.org/48/18/players/167495.png
# 5     R. Lewandowski   28  https://cdn.sofifa.org/48/18/players/188545.png
# 6             De Gea   26  https://cdn.sofifa.org/48/18/players/193080.png
# 7          E. Hazard   26  https://cdn.sofifa.org/48/18/players/183277.png
# 8           T. Kroos   27  https://cdn.sofifa.org/48/18/players/182521.png
# 9         G. Higuaín   29  https://cdn.sofifa.org/48/18/players/167664.png
#
#   Nationality                                 Flag  Overall  Potential  \
# ...

# %%
#checking for missing value columns
data.isna().sum()
# Out:
# Name              0
# Age               0
# Photo             0
# Nationality       0
# Flag              0
#                ...
# RM             2029
# RS             2029
# RW             2029
# RWB            2029
# ST             2029
# Length: 74, dtype: int64

# %%
#checking for missing value in string columns
data['Club'].isna().values.any()
# Out:
# True

# %%
#filling missing value and checking
data['Club'].fillna(data['Club'].value_counts().index[0],inplace=True)
data['Club'].isna().values.any()
# Out:
# False

# %%
#checking for missing value in string columns
data['Club Logo'].isna().values.any()
# Out:
# False

# %%
#checking for missing value in string columns
data['Preferred Positions'].isna().values.any()
# Out:
# False

# %%
#applying for loop for checking and replacing missing values with mean
for col in data:
    if data[col].isna().values.any()==True:
        data[col].fillna(data[col].mean(), inplace=True)
        
#finding if any value is missing
data.isna().values.any()
# Out:
# False

# %%
#for confirmation againg checking count of missing values
data.isna().sum().sum()
# Out:
# 0

# %%
#finding size of dataset
data.shape
# Out:
# (17981, 74)

# %%
#saving this corrected file in csv format
data.to_csv('FIFA_Project.csv')
